# %% [markdown]
# <a href="https://colab.research.google.com/github/murlishriyan/Capstone-project/blob/main/Play_store_app_EDA_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Project Name - Play Store App Review Analysis**

# %% [markdown]
# Project Type - EDA
#
# Contribution - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>
#
# **In this project, I used Exploratory Data Analysis (EDA) approach to analyze the data using visual techniques and discover Trends, and Patterns, or to check assumptions with the help of statistical summaries and graphical representations.**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# *  What are the top categories on which contains most?
# *  what are the least five category based on number of listed application?
# *  what is the ratio of number of paid apps and free apps?
# *  how man percentage of apps are there based on category?
# *  which category has the most number of installtions?
# *  which size does the most application have?
# *  which are the most downloaded application in the play store?
# *  how many ratings does most of the app contain?
# *  Distribution of App update over the Year?
# *  what is the percentage of reviews sentiments?
# *  which application has highest no of positve rating?
# *  is subjectivity and polarity propotional to each other?

# %% [markdown]
# # **What is Exploratory Data Analysis?**
# Exploratory data analysis (EDA) is used by data scientists to analyze and investigate data sets for patterns, and anomalies (outliers), and form hypotheses based on our understanding of the dataset and summarize their main characteristics, often employing data visualization methods. It is an important step in any Data Analysis or Data Science project. It helps determine how best to manipulate data sources to get the answers you need.
#
# EDA involves generating summary statistics for numerical data in the dataset and creating various graphical representations to understand the data better and make it more attractive and appealing.
#
# The following are the various steps involved in the EDA process:
# 1. <b>Problem Statement</b> - We shall brainstorm and understand the given data set. We shall study the attributes present in it and try to do a philosophical analysis about their meaning and importance for this problem.
# 3. <b>Univariate Analysis</b> - It is the simplest form of analyzing the data. In this we would initially pick up a single attribute and study it in and out. It doesn't deal with any sort of co-relation and it's major purpose is to describe. It takes data, summarizes that data and finds patterns in the data.
# 4. <b>Bivariate Analysis</b> - This analysis is related to cause and the relationship between the two attributes. We will try to understand the dependency of attributes on each other.
# 5. <b>Multivariate Analysis</b> - This is done when more than two variables have to be analyzed simultaneously.
# 6. <b>Data Cleaning</b> - We shall clean the dataset and handle the missing data, outliers and categorical variables.
# 7. <b>Testing Hypothesis</b> - We shall check if our data meets the assumptions required by most of the multivariate techniques.

# %% [markdown]
# ## **1. Know Your Data**

# %%
#import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#loading csv file
df=pd.read_csv('/content/Play Store Data.csv')

# %%
# Display the Play Store App data
pd.concat([df.head(),df.tail()])
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#rating statistics 
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
#list of columns
list(df.columns)
# Out:
# ['App',
#  'Category',
#  'Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %% [markdown]
# Let us first define what information the columns contain based on our inspection.
#
# play_store dataframe has 10841 rows and 13 columns. The 13 columns are identified as below:
#
# 1.   App - It tells us about the name of the application with a short description (optional).
# 1.   Category - It gives the category to the app.
# 1.   Rating - It contains the average rating the respective app received from its users.
# 1.   Reviews - It tells us about the total number of users who have given a review for the application.
# 1.  Size - It tells us about the size being occupied the application on the mobile phone.
# 2.   Installs - It tells us about the total number of installs/downloads for an application.
# 2.   Type - IIt states whether an app is free to use or paid.
# 2.   Price - It gives the price payable to install the app. For free type apps, the price is zero.
# 2.  Content Rating - It states whether or not an app is suitable for all age groups or not.
# 1.  Genres - It tells us about the various other categories to which an application can belong.
# 2.  Last Updated - It tells us about the when the application was updated.
# 2.   Current Ver - It tells us about the current version of the application.
# 1.  Android Ver - It tells us about the android version which can support the application on its platform.

# %% [markdown]
# #**Data Cleaning**

# %% [markdown]
# #missing values

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# # Findings
#
# Rating has 1474 null values. Type has 1 null value . Content_Rating has 1 null value. Current_Ver has 8 null values . Android_Ver has 3 null values

# %%
# The rows containing NaN values in the Android Ver column
df[df['Android Ver'].isnull()]
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#       Reviews    Size Installs  Type     Price Content Rating  \
# 4453      230     11M   1,000+  Paid     $1.49       Everyone
# 4490      189    2.1M  10,000+  Free         0       Everyone
# 10472    3.0M  1,000+     Free     0  Everyone            NaN
#
#                   Genres    Last Updated Current Ver Android Ver
# 4453     Personalization   July 20, 2018         4.4         NaN
# 4490     Personalization  March 27, 2018         1.1         NaN
# 10472  February 11, 2018          1.0.19  4.0 and up         NaN

# %%
# Finding the different values the 'Android Ver' column takes
df['Android Ver'].value_counts()
# Out:
# 4.1 and up            2451
# 4.0.3 and up          1501
# 4.0 and up            1375
# Varies with device    1362
# 4.4 and up             980
# 2.3 and up             652
# 5.0 and up             601
# 4.2 and up             394
# 2.3.3 and up           281
# 2.2 and up             244
# 4.3 and up             243
# 3.0 and up             241
# 2.1 and up             134
# 1.6 and up             116
# 6.0 and up              60
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              24
# 1.5 and up              20
# 4.4W and up             12
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %%
# dropping rows corresponding to the to the NaN values in the 'Android Ver' column.
df=df[df['Android Ver'].notna()]

# %%
# Finding the different values the 'Current Ver' column takes
df['Current Ver'].value_counts()
# Out:
# Varies with device    1459
# 1.0                    809
# 1.1                    263
# 1.2                    178
# 2.0                    151
#                       ...
# 5.44.1                   1
# 7.16.8                   1
# 04.08.00                 1
# 2.10.06                  1
# 2.0.148.0                1
# Name: Current Ver, Length: 2831, dtype: int64

# %%
# dropping rows corresponding to the to the NaN values in the 'Current Ver' column.
df=df[df['Current Ver'].notna()]

# %%
# Finding the different values the 'Type' column takes
df['Type'].value_counts()
# Out:
# Free    10032
# Paid      797
# Name: Type, dtype: int64

# %%
# Replacing the NaN value in 'Type' column corresponding to row index 9148 with 'Free'
df.loc[9148,'Type']='Free'

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1470
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# dtype: int64

# %%
# The rows containing NaN values in the Rating column
df[df['Rating'].isnull()]
# Out:
#                                        App             Category  Rating  \
# 23                  Mcqueen Coloring pages       ART_AND_DESIGN     NaN
# 113              Wrinkles and rejuvenation               BEAUTY     NaN
# 123                 Manicure - nail design               BEAUTY     NaN
# 126           Skin Care and Natural Beauty               BEAUTY     NaN
# 129    Secrets of beauty, youth and health               BEAUTY     NaN
# ...                                    ...                  ...     ...
# 10824                            Cardio-FR              MEDICAL     NaN
# 10825                   Naruto & Boruto FR               SOCIAL     NaN
# 10831             payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                             FR Forms             BUSINESS     NaN
# 10838               Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews  Size  Installs  Type Price Content Rating  \
# ...

# %%
# Finding mean and median in the Rating column excluding the NaN values.
mean_of_rating = round(df[~df['Rating'].isnull()]['Rating'].mean(),3)
mean_of_rating
# Out:
# 4.192

# %%
median_of_rating = df[~df['Rating'].isnull()]['Rating'].median()
median_of_rating
# Out:
# 4.3

# %%
sns.distplot(df['Rating'],color='red')

# %% [markdown]
# The mean of average rating is 4.2 and
# Median is 4.3
#
# From the distplot visualizations, it is clear that the ratings are left skewed.
#
# Hence we will impute the NaN values in the Rating column with its median.

# %%
# Replacing the NaN values in the 'Rating' colunm with its median value
df['Rating'].fillna(value=median_of_rating,inplace=True)

# %% [markdown]
# # **Handling Duplicate values**

# %%
#checking dupilcate in App columns
df['App'].value_counts()
# Out:
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# Candy Crush Saga                                      7
# 8 Ball Pool                                           7
# ESPN                                                  7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: App, Length: 9649, dtype: int64

# %%
#checking duplicate values
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
# dropping duplicates from the 'App' column.
df.drop_duplicates(subset='App',inplace=True)

# %%
#last updated column is not in date time type
df['Last Updated']
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10836       July 25, 2017
# 10837        July 6, 2018
# 10838    January 20, 2017
# 10839    January 19, 2015
# 10840       July 25, 2018
# Name: Last Updated, Length: 9649, dtype: object

# %%
#coverting last updated column data type to date time
df['Last Updated'] = pd.to_datetime(df['Last Updated'])

# %%
df['Price'].value_counts()
# Out:
# 0          8896
# $0.99       143
# $2.99       124
# $1.99        73
# $4.99        70
#            ...
# $18.99        1
# $389.99       1
# $19.90        1
# $1.75         1
# $1.04         1
# Name: Price, Length: 92, dtype: int64

# %% [markdown]
# so here we can see there are dolar symbol ($) and the data type is not float
#
# > Indented block

# %%
#creating a function to drop dollar ($) and converting the type into float
def dollar_conv(num):
  if '$' in num:
    return float(num[1:])
  else:
    return float(num)

# %%
df['Price']=df['Price'].apply(lambda x: dollar_conv(x))

# %%
df['Price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# coverted to float

# %%
df['Price'].value_counts()
# Out:
# 0.00      8896
# 0.99       143
# 2.99       124
# 1.99        73
# 4.99        70
#           ...
# 18.99        1
# 389.99       1
# 19.90        1
# 1.75         1
# 1.04         1
# Name: Price, Length: 92, dtype: int64

# %% [markdown]
# removed $ in the price column

# %%
#checking size column
df['Size'].value_counts()
# Out:
# Varies with device    1227
# 12M                    181
# 11M                    181
# 13M                    177
# 14M                    176
#                       ...
# 721k                     1
# 430k                     1
# 429k                     1
# 200k                     1
# 619k                     1
# Name: Size, Length: 457, dtype: int64

# %% [markdown]
# so here we need to covert kb in mb (where M is mb and k is kb)

# %%
#creating a function to covert kb into mb
def convert_kb(num):
  if 'M' in num:
    return float(num[:-1])
  elif 'k' in num:
    return round(float(num[:-1])/1024,4)
  else:
    return num

# %%
df['Size']=df['Size'].apply(lambda x :convert_kb(x))

# %%
df['Size'].value_counts()
# Out:
# Varies with device    1227
# 12.0                   181
# 11.0                   181
# 13.0                   177
# 14.0                   176
#                       ...
# 0.7041                   1
# 0.4199                   1
# 0.4189                   1
# 0.1953                   1
# 0.6045                   1
# Name: Size, Length: 456, dtype: int64

# %% [markdown]
# converted the size column from kb to mb

# %%
df[df['Size']=='Varies with device']
# Out:
#                                                      App             Category  \
# 37                                    Floor Plan Creator       ART_AND_DESIGN
# 42                            Textgram - write on photos       ART_AND_DESIGN
# 52                         Used Cars and Trucks for Sale    AUTO_AND_VEHICLES
# 67                                    Ulysse Speedometer    AUTO_AND_VEHICLES
# 68                                                REPUVE    AUTO_AND_VEHICLES
# ...                                                  ...                  ...
# 10713  My Earthquake Alerts - US & Worldwide Earthquakes              WEATHER
# 10725                                          Posta App  MAPS_AND_NAVIGATION
# 10765                    Chat For Strangers - Video Chat               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
#
# ...

# %% [markdown]
# here we can see that in size column there are 1227 entries which contains 'varies with device'

# %%
#converting to Nan and making it as float for further analysis
df['Size'] = df['Size'].apply(lambda x: str(x).replace('Varies with device', 'NaN') if 'Varies with device' in str(x) else x)
df['Size'] = df['Size'].apply(lambda x: float(x))

# %%
fig, ax = plt.subplots(2,1, figsize=(12,7))
sns.distplot(df[df['Size'] != 'Varies with device']['Size'], color='purple', ax=ax[0])
sns.boxplot(x='Size',data=df, ax=ax[1])

# %% [markdown]
# so here the size data is right skewed and there are many entries of 'varies with device' so we cannot replace it with central tendancy

# %%
#Checking for install column
df['Installs'].value_counts()
# Out:
# 1,000,000+        1416
# 100,000+          1112
# 10,000+           1029
# 10,000,000+        937
# 1,000+             886
# 100+               709
# 5,000,000+         607
# 500,000+           504
# 50,000+            468
# 5,000+             467
# 10+                384
# 500+               328
# 50+                204
# 50,000,000+        202
# 100,000,000+       188
# 5+                  82
# 1+                  67
# 500,000,000+        24
# 1,000,000,000+      20
# 0+                  14
# 0                    1
# Name: Installs, dtype: int64

# %% [markdown]
# here we have to drop '+' and , in the installs column and convert into integer data type

# %%
#creating a function to drop + and , 
def drop_inst(num):
  if '+' and ',' in num:
    new = int(num[:-1].replace(',',''))
    return new
  elif '+' in num:
    new1 = int(num[:-1])
    return new1
  else:
    return int(num)

# %%
df['Installs']=df['Installs'].apply(lambda x :drop_inst(x))
df['Installs'].head()
# Out:
# 0       10000
# 1      500000
# 2     5000000
# 3    50000000
# 4      100000
# Name: Installs, dtype: int64

# %% [markdown]
# converted to integer and dropped + and ,

# %%
#converting Reviews column data type to integer
df['Reviews'].dtype
# Out:
# dtype('O')

# %%
df['Reviews']=df['Reviews'].astype(int)
df['Reviews'].dtype
# Out:
# dtype('int64')

# %%
 df.describe()
# Out:
#             Rating       Reviews         Size      Installs        Price
# count  9649.000000  9.649000e+03  8422.000000  9.649000e+03  9649.000000
# mean      4.192476  2.168145e+05    20.413556  7.785404e+06     1.100079
# std       0.496528  1.832255e+06    21.833485  5.378557e+07    16.860857
# min       1.000000  0.000000e+00     0.008300  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01     4.600000  1.000000e+03     0.000000
# 50%       4.300000  9.690000e+02    12.000000  1.000000e+05     0.000000
# 75%       4.500000  2.944500e+04    28.000000  1.000000e+06     0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09   400.000000

# %% [markdown]
# # **Exploring User_review dataframe**

# %%
df1=pd.read_csv('/content/User Reviews (2).csv')

# %%
# Checking the top 10 rows of the data

df1.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
#checking info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
list(df1.columns)
# Out:
# ['App',
#  'Translated_Review',
#  'Sentiment',
#  'Sentiment_Polarity',
#  'Sentiment_Subjectivity']

# %%
#checling for null values
df1.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
df1[df1.isnull()]
# Out:
#        App Translated_Review Sentiment  Sentiment_Polarity  \
# 0      NaN               NaN       NaN                 NaN
# 1      NaN               NaN       NaN                 NaN
# 2      NaN               NaN       NaN                 NaN
# 3      NaN               NaN       NaN                 NaN
# 4      NaN               NaN       NaN                 NaN
# ...    ...               ...       ...                 ...
# 64290  NaN               NaN       NaN                 NaN
# 64291  NaN               NaN       NaN                 NaN
# 64292  NaN               NaN       NaN                 NaN
# 64293  NaN               NaN       NaN                 NaN
# 64294  NaN               NaN       NaN                 NaN
#
#        Sentiment_Subjectivity
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 64290                     NaN
# ...

# %% [markdown]
# here we can see that all the columns contain null value so that we can drop nan values

# %%
# Deleting the rows containing NaN values
df1 = df1.dropna()

# %%
df1.shape
# Out:
# (37427, 5)

# %%
df1.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %% [markdown]
# the updated user review data contains 37427 rows and 5 columns

# %% [markdown]
# #**Data Wrangling**

# %%
#creating a data frame contaning total number of app based on category
app_cat=df.groupby('Category')['App'].nunique().reset_index(name='Total app')
app_cat=app_cat.sort_values(by=['Total app'],ascending = False)
app_cat
# Out:
#                Category  Total app
# 11               FAMILY       1829
# 14                 GAME        959
# 29                TOOLS        825
# 4              BUSINESS        420
# 20              MEDICAL        395
# 23      PERSONALIZATION        374
# 25         PRODUCTIVITY        374
# 18            LIFESTYLE        369
# 12              FINANCE        345
# 28               SPORTS        325
# 6         COMMUNICATION        315
# 15   HEALTH_AND_FITNESS        288
# 24          PHOTOGRAPHY        281
# 21   NEWS_AND_MAGAZINES        254
# 27               SOCIAL        239
# 3   BOOKS_AND_REFERENCE        221
# 30     TRAVEL_AND_LOCAL        219
# 26             SHOPPING        202
# 7                DATING        171
# 31        VIDEO_PLAYERS        163
# 19  MAPS_AND_NAVIGATION        131
# 8             EDUCATION        119
# 13       FOOD_AND_DRINK        112
# 9         ENTERTAINMENT        102
# 1     AUTO_AND_VEHICLES         85
# 17   LIBRARIES_AND_DEMO         83
# ...

# %%
#creating a dataframe which contains less applications in category
least_category = app_cat.sort_values(by=['Total app'],ascending = False)
least_category=least_category.tail()

# %%
least_category.reset_index()
# Out:
#    index        Category  Total app
# 0     10          EVENTS         64
# 1      0  ART_AND_DESIGN         63
# 2     22       PARENTING         60
# 3      5          COMICS         56
# 4      2          BEAUTY         53

# %%
#data containing number of installation based on category
num_install = df.groupby('Category')['Installs'].sum().reset_index()
num_install = num_install.sort_values(by = 'Installs',ascending=False)
num_install
# Out:
#                Category     Installs
# 14                 GAME  13878924415
# 6         COMMUNICATION  11038276251
# 29                TOOLS   8001271905
# 25         PRODUCTIVITY   5793091369
# 27               SOCIAL   5487867902
# 24          PHOTOGRAPHY   4649147655
# 11               FAMILY   4427881405
# 31        VIDEO_PLAYERS   3926902720
# 30     TRAVEL_AND_LOCAL   2894887146
# 21   NEWS_AND_MAGAZINES   2369217760
# 9         ENTERTAINMENT   2113660000
# 3   BOOKS_AND_REFERENCE   1665968576
# 23      PERSONALIZATION   1532483782
# 26             SHOPPING   1400348785
# 15   HEALTH_AND_FITNESS   1144022512
# 28               SPORTS   1096474498
# 4              BUSINESS    697164865
# 18            LIFESTYLE    503823539
# 19  MAPS_AND_NAVIGATION    503281890
# 12              FINANCE    455348734
# 32              WEATHER    361100520
# 8             EDUCATION    352952000
# 13       FOOD_AND_DRINK    211798751
# 7                DATING    140926107
# ...

# %%
#contaning reviewa,size,installs,price based on rating
rating_df = df.groupby('Rating').sum().reset_index()
rating_df
# Out:
#     Rating    Reviews        Size     Installs    Price
# 0      1.0         28    228.8000         5170     4.48
# 1      1.2         44     27.0000         1000     0.00
# 2      1.4         98     20.2000         7000     0.00
# 3      1.5         61     54.0000         1105     0.00
# 4      1.6        691     64.6000       152000     0.00
# 5      1.7       2360     80.3000        81700     4.99
# 6      1.8       3418     49.0662       519500     1.49
# 7      1.9       1874    154.2000       189000     0.00
# 8      2.0       2997    191.4000      5040150     4.59
# 9      2.1       3073    164.2000       182000     0.00
# 10     2.2       1979    217.4000      2130600     0.00
# 11     2.3       2361    344.6000       264100     2.48
# 12     2.4      14829    275.7806      1284100     5.98
# 13     2.5      14807    359.8512      2078100     3.99
# 14     2.6       3761    242.8211       442600    16.98
# 15     2.7      25048    363.1660      3359700     7.98
# ...

# %%
# Function to group the apps based on its size in MB

def size_apps(var):
  '''
  This function groups the size of an app 
  between ~0 to 100 MB into certain intervals.
  '''
  try:
    if var < 1:
      return 'Below 1'
    elif var >= 1 and var <10:
      return '1-10'
    elif var >= 10 and var <20:
      return '10-20'
    elif var >= 20 and var <30:
      return '20-30'
    elif var >= 30 and var <40:
      return '30-40'
    elif var >= 40 and var <50:
      return '40-50'
    elif var >= 50 and var <60:
      return '50-60'
    elif var >= 60 and var <70:
      return '60-70'
    elif var >= 70 and var <80:
      return '70-80'
    elif var >= 80 and var <90:
      return '80-90'
    else:
      return '90 and above'
  except:
    return var

# %%
df['size_group']=df['Size'].apply(lambda x : size_apps(x))
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
# Creating a df containing only paid apps
paid_df = df[df['Type'] == 'Paid']
paid_df.head()
# Out:
#                                                App       Category  Rating  \
# 234  TurboScan: scan documents and receipts in PDF       BUSINESS     4.7
# 235                 Tiny Scanner Pro: PDF Doc Scan       BUSINESS     4.8
# 427                             Puffin Browser Pro  COMMUNICATION     4.0
# 476                      Moco+ - Chat, Meet People         DATING     4.2
# 477                                     Calculator         DATING     2.6
#
#      Reviews  Size  Installs  Type  Price Content Rating         Genres  \
# 234    11442   6.8    100000  Paid   4.99       Everyone       Business
# 235    10295  39.0    100000  Paid   4.99       Everyone       Business
# 427    18247   NaN    100000  Paid   3.99       Everyone  Communication
# 476     1545   NaN     10000  Paid   3.99     Mature 17+         Dating
# 477       57   6.2      1000  Paid   6.99       Everyone         Dating
#
#     Last Updated  Current Ver Android Ver    size_group
# ...

# %%
# Creating a df containing only Free apps
free_df =df[df['Type'] == 'Free']
free_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
#extracting the year and storing to new column as integer
paid_df["Update year"] = paid_df["Last Updated"].apply(lambda x: x.strftime('%Y')).astype('int64') 
free_df["Update year"] = free_df["Last Updated"].apply(lambda x: x.strftime('%Y')).astype('int64')

# %%
#data contaning positive reviews
sent_positive = df1[df1['Sentiment']=='Positive']
sent_positive
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# 5               10 Best Foods for You
# ...                               ...
# 64217  Housing-Real Estate & Property
# 64221  Housing-Real Estate & Property
# 64222  Housing-Real Estate & Property
# 64223  Housing-Real Estate & Property
# 64227  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# ...                                                  ...       ...
# ...

# %%
#data contaning negative reviews
sent_negative = df1[df1['Sentiment']=='Negative']
sent_negative
# Out:
#                                   App  \
# 32              10 Best Foods for You
# 43              10 Best Foods for You
# 68              10 Best Foods for You
# 85              10 Best Foods for You
# 95              10 Best Foods for You
# ...                               ...
# 64215  Housing-Real Estate & Property
# 64216  Housing-Real Estate & Property
# 64220  Housing-Real Estate & Property
# 64226  Housing-Real Estate & Property
# 64230  Housing-Real Estate & Property
#
#                                        Translated_Review Sentiment  \
# 32                    No recipe book Unable recipe book.  Negative
# 43     Waste time It needs internet time n ask calls ...  Negative
# 68                               Faltu plz waste ur time  Negative
# 85                                     Crap Doesn't work  Negative
# 95     Boring. I thought actually just texts that's i...  Negative
# ...                                                  ...       ...
# ...

# %% [markdown]
# #**Data Visualization**

# %%
#bar graph on app category
plt.figure(figsize=(20,6))
sns.barplot(data=app_cat,x="Category",y="Total app")
plt.xticks(rotation= 90)
plt.title("Total app based on category",fontsize=16)
plt.xlabel("category",fontsize=14)
plt.ylabel("total app",fontsize=14)
warnings.filterwarnings("ignore")

# %% [markdown]
# here we can see that top 3 Category (Family,Game,Tools) that has the most application

# %%
#Least 5 category based on listed app
fig = plt.figure(figsize=(7,5))
sns.barplot(data=least_category,x='Category',y='Total app')

warnings.filterwarnings("ignore")

# %% [markdown]
# Least five categories were apps are least listed are
#
# Beauty
#
# Comics
#
# Parenting
#
# Art and Design
#
# Events

# %%
#ratio of free app vs paid app dowloaded
data=df['Type'].value_counts()
labels=['Free','Paid']
plt.figure(figsize=(7,7))
explode=(0.01,0.1)
plt.pie(data,labels=labels,autopct='%.2f%%')
plt.title('Distribution of Paid and Free apps',size=15)
plt.legend()

# %% [markdown]
# From the above graph we can see that 92% of apps in google play store are free and 8%are paid.

# %%
# percentage of no of app based on category
plt.figure(figsize=(18,18))
plt.pie(df.Category.value_counts(), labels=df.Category.value_counts().index, autopct='%1.2f%%')
warnings.filterwarnings("ignore")

# %% [markdown]
# so here we can see that most of the applications are under family category which is 18.96%.

# %%
#number app installed based on category
plt.figure(figsize=(20,10))
sns.barplot(x='Category',y='Installs',data=num_install)
plt.xticks(rotation = 90)
plt.xlabel("Category",fontsize=16)
plt.ylabel('Installs (e+10)',fontsize=16)
plt.title('Number of Installs For Each Category',fontsize=16)
plt.show()
warnings.filterwarnings("ignore")

# %% [markdown]
# In this plot we can see that most of the app are installed in game and communication category

# %%
#distibution of size
plt.figure(figsize=(10, 6))
plt.hist(df['Size'],color = "skyblue")
plt.xlabel("Size",fontsize=16)
plt.title("Distribution of Size",fontsize=16)
plt.ylabel("Number of apps",fontsize=16)
plt.show()

# %% [markdown]
# This histogram tells us that most of apps are of size less than 20 MB

# %%
df['size_group'].value_counts().plot.barh(figsize=(20,8),color='r').invert_yaxis()
plt.title("Number of apps in different size groups", size=20)
plt.ylabel('App size in MB', size=15)
plt.xlabel('No of apps', size=15)
plt.legend()

# %%
# average number of app installs 
df.groupby('size_group')['Installs'].mean().sort_values(ascending= False).plot.barh(figsize=(20,8),color='sandybrown').invert_yaxis()
plt.title("Average number of app installs (In 10 millions)", size=20)
plt.ylabel('App size in MB', size=15)
plt.xlabel('Average no of app installs',  size=15)
plt.legend()

# %% [markdown]
# here most of the application are installed which has size more than 70 mb

# %%
#plot of reviews,size,install,price with respect to ratings
fig, axes = plt.subplots(1,3,figsize=(12,5))

axes[0].plot(rating_df['Rating'],rating_df['Reviews'],'g')
axes[0].set_xlabel('Rating')
axes[0].set_ylabel('Reviews')
axes[0].set_title('no of reviws per rating')

axes[1].plot(rating_df['Rating'], rating_df['Installs'], 'y')
axes[1].set_xlabel('Rating')
axes[1].set_ylabel('Installs (e+10)')
axes[1].set_title('no of Installs Per Rating')

axes[2].plot(rating_df['Rating'], rating_df['Price'], 'm')
axes[2].set_xlabel('Rating')
axes[2].set_ylabel('Price')
axes[2].set_title('no  of Price Per Rating')

plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# In this plot we can see that most of app are installed based on good rating which is between 4-5

# %%
#top 10 downloaded application in play store
app_install = df.sort_values(by=['Installs'],ascending = False).head(10)
graph = sns.barplot(x = app_install.App, y = app_install.Installs, palette= "icefire")
graph.set_xticklabels(graph.get_xticklabels(), rotation= 45, horizontalalignment='right')
warnings.filterwarnings("ignore")

# %% [markdown]
# These are the top 10 apps which is most downloded (1 billion)

# %%
df.corr()
# Out:
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.050212  0.045528  0.034306 -0.018674
# Reviews   0.050212  1.000000  0.179275  0.625158 -0.007603
# Size      0.045528  0.179275  1.000000  0.134216 -0.022494
# Installs  0.034306  0.625158  0.134216  1.000000 -0.009412
# Price    -0.018674 -0.007603 -0.022494 -0.009412  1.000000

# %%
#correlation of variable using heatmap
fig, axes = plt.subplots(figsize=(8, 8))
sns.heatmap(df.corr(),ax=axes,linewidths=0.1,annot=True,fmt='.2f')
plt.title('correlation of variables',fontsize=16)
# Out:
# Text(0.5, 1.0, 'correlation of variables')

# %% [markdown]
# 1-The correlation between reviews and price is very low
#
# 2-the correlation between reviews and installation is very high
#
# 3- the moderate correlation variables are size vs reviews,

# %%
# Average app ratings
df['Rating'].value_counts().plot.bar(figsize=(20,8), color = 'y' )
plt.xlabel('Average rating',fontsize = 15 )
plt.ylabel('Number of apps', fontsize = 15)
plt.title('Average rating of apps in Playstore', fontsize = 20)
plt.legend()

# %% [markdown]
# We can group rating in following intervals
# *   4-5: Top rated
# *   3-4: Above average
# *   2-3: Average
# *   1-2: Below average
# most of the application contains good reviews

# %%
plt1 = plt.figure(figsize=(10,7))
paid_df.groupby("Update year")["App"].count().plot.line(marker='o')
free_df.groupby('Update year')['App'].count().plot.line(marker='o')

# %% [markdown]
# In this plot we can see that there were no paid application till 2011 and the free apps are added more year by year

# %%
#checking the sentiment percentage in user review data
plt.figure(figsize=(8,6))
plt.title("sentiment percentege",fontsize = 16)
plt.pie(df1.Sentiment.value_counts(), labels=df1.Sentiment.value_counts().index,autopct='%1.1f%%',startangle=90)
plt.show()

# %% [markdown]
# so here we can say that positve rating is more

# %%
#Apps with the highest number of positive reviews
sent_positive.groupby('App')['Sentiment'].value_counts().nlargest(10).plot.barh(figsize=(10,6),color='green').invert_yaxis()
plt.title("Top 10 positive review apps")
plt.xlabel('Total number of positive reviews')
plt.legend()

# %% [markdown]
# In the plot we can see that top 10 app wich contains most positive reviews

# %%
#Apps with the highest number of negative reviews.
sent_negative.groupby('App')['Sentiment'].value_counts().nlargest(10).plot.barh(figsize=(10,6),color='red').invert_yaxis()
plt.title("Top 10 negative review apps")
plt.xlabel('Total number of negative reviews')
plt.legend()

# %% [markdown]
# These are the top 10 apps which contains most negative reviews

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(data=df1,x='Sentiment_Subjectivity', y='Sentiment_Polarity',hue="Sentiment")
plt.title("Does sentiment_subjectivity proportional to sentiment_polarity",fontsize=16)
plt.show()

# %% [markdown]
# From the above scatter plot it can be concluded that sentiment subjectivity is not always proportional to sentiment polarity but in maximum number of case, shows a proportional behavior, when variance is too high or low

# %% [markdown]
# # **conclusions-**

# %% [markdown]
# In this analysis of play store review data we have gained lots of insights.we have analysed the applications in the play store with diffrent methods.cleaned the data by replacing the missing values and checking for the duplicates.
# later did data wrangling to tranfrom the data into information that we get.plotted various graph using matplotlib and seaborn to get useful insights from it.
# These are some insights we got while analysing
#
# * Percentage of free apps = ~92%
# * Percentage of apps with no age restrictions = ~82%
# * Most competitive category: Family
# * Category with the highest average app installs: Game
# * Percentage of apps that are top rated = ~80%
# * Family, Game and Tools are top three categories having 1906, 926 and 829 app count.
# * There are 20 free apps that have been installed over a billion times.
# * Minecraft is the only app in the paid category with over 10M installs. This app has also produced the most revenue only from the installation fee.
# * Category in which the paid apps have the highest average installation fee: Finance
# * The apps whose size is greater than 90 MB has the highest number of average user reviews, ie, they are more popular than the rest.
# * Helix Jump has the highest number of positive reviews and Angry Birds Classic has the highest number of negative reviews.
# * Overall sentiment count of dataset in which Positive sentiment count is 64%, Negative 22% and Neutral 13%.
